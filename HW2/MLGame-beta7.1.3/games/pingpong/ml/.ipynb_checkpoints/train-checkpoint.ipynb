# %%
import pickle
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import  classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import cluster, metrics

file = open("../log/train (1).pickle", "rb")
data = pickle.load(file)
file.close()
scene_info = data['scene_info']
scene_command = data['command']

for i in range(2, 51):
    path = "../log/train (" + str(i) + ").pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    scene_info = scene_info + data['scene_info']
    scene_command = scene_command + data['command']
    file.close()
    
print(len(scene_info))
print(len(scene_command))
print(scene_command)
# Out:
# 41281
# 41281
# [['SERVE_TO_RIGHT', 'SERVE_TO_LEFT'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], [None, None], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'NONE'], ['NONE', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['NONE', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['NONE', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['NONE', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['NONE', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['NONE', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'NONE'], ['NONE', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['NONE', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'MOVE_LEFT'], ['MOVE_RIGHT', 'NONE'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['NONE', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'MOVE_RIGHT'], ['MOVE_LEFT', 'NONE'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'MOVE_LEFT'], ['MOVE_LEFT', 'NONE'], ['MOVE_RIGHT', 'MOVE_RIGHT'], ['MOVE_LEF ...

# %%
Ball_x = []
Ball_y = []
Ball_speed_x = []
Ball_speed_y = []
Platform_1P = []
Platform_2P = []
blocker_x = []
blocker_y = []
command = []
count = 0

for i, s in enumerate(scene_info[1:-2]):
    Ball_x.append(s['ball'][0])
    Ball_y.append(s['ball'][1])
    Ball_speed_x.append(s['ball_speed'][0])
    Ball_speed_y.append(s['ball_speed'][1])
    Platform_1P.append(s['platform_1P'][0])
    Platform_2P.append(s['platform_2P'][0])
    blocker_x.append(s['blocker'][0])
    blocker_y.append(s['blocker'][1])

for i, s in enumerate(scene_command[1:-2]):
    count = count + 1
    print(count)
for i, s in enumerate(scene_command[1:-2]):
    print(s[0], s[1])
    if s[0] == "NONE" and s[1] == "NONE":
        command.append(0)
    elif s[0] == "NONE" and s[1] == "MOVE_LEFT":
        command.append(1)
    elif s[0] == "NONE" and s[1] == "MOVE_RIGHT":
        command.append(2)
    elif s[0] == "MOVE_LEFT" and s[1] == "NONE":
        command.append(3)
    elif s[0] == "MOVE_LEFT" and s[1] == "MOVE_LEFT":
        command.append(4)
    elif s[0] == "MOVE_LEFT" and s[1] == "MOVE_RIGHT":
        command.append(5)
    elif s[0] == "MOVE_RIGHT" and s[1] == "NONE":
        command.append(6)
    elif s[0] == "MOVE_RIGHT" and s[1] == "MOVE_LEFT":
        command.append(7)
    elif s[0] == "MOVE_RIGHT" and s[1] == "MOVE_RIGHT":
        command.append(8)

numpy_feature_data = np.array([Ball_x, Ball_y, Ball_speed_x, Ball_speed_y, Platform_1P, Platform_2P, blocker_x, blocker_y])
feature = np.transpose(numpy_feature_data) 
numpy_answer_data = np.array([command])
answer = np.transpose(numpy_answer_data)

print(feature)
print(feature.shape)
print(answer)
print(answer.shape)
# Out:
# 1 NONE
# 2 NONE
# 3 NONE
# 4 NONE
# 5 NONE
# 6 NONE
# 7 NONE
# 8 NONE
# 9 NONE
# 10 NONE
# 11 NONE
# 12 NONE
# 13 NONE
# 14 NONE
# 15 NONE
# 16 NONE
# 17 NONE
# 18 NONE
# 19 NONE
# 20 NONE
# 21 NONE
# 22 NONE
# 23 NONE
# 24 NONE
# 25 NONE
# 26 NONE
# 27 NONE
# 28 NONE
# 29 NONE
# 30 NONE
# 31 NONE
# 32 NONE
# 33 NONE
# 34 NONE
# 35 NONE
# 36 NONE
# 37 NONE
# 38 NONE
# 39 NONE
# 40 None
# 41 NONE
# 42 NONE
# 43 NONE
# 44 NONE
# 45 NONE
# 46 NONE
# 47 NONE
# 48 NONE
# 49 NONE
# 50 MOVE_RIGHT
# 51 MOVE_LEFT
# 52 MOVE_LEFT
# 53 MOVE_LEFT
# 54 MOVE_LEFT
# 55 MOVE_LEFT
# 56 MOVE_LEFT
# 57 MOVE_LEFT
# 58 MOVE_LEFT
# 59 MOVE_LEFT
# 60 NONE
# 61 MOVE_RIGHT
# 62 NONE
# 63 NONE
# 64 NONE
# 65 NONE
# 66 MOVE_RIGHT
# 67 MOVE_RIGHT
# 68 NONE
# 69 MOVE_LEFT
# 70 NONE
# 71 MOVE_RIGHT
# 72 NONE
# 73 NONE
# 74 MOVE_LEFT
# 75 MOVE_LEFT
# 76 NONE
# 77 MOVE_RIGHT
# 78 MOVE_RIGHT
# 79 MOVE_RIGHT
# 80 MOVE_LEFT
# 81 MOVE_LEFT
# 82 NONE
# 83 MOVE_RIGHT
# 84 NONE
# 85 MOVE_LEFT
# 86 MOVE_RIGHT
# 87 MOVE_RIGHT
# 88 NONE
# 89 MOVE_LEFT
# 90 NONE
# 91 NONE
# 92 NONE
# 93 NONE
# 94 MOVE_RIGHT
# 95 MOVE_RIGHT
# 96 MOVE_LEFT
# 97 MOVE_LEFT
# 98 MOVE_RIGHT
# 99 MOVE_RIGHT
# 100 MOVE_RIGHT
# 101 MOVE_RIGHT
# 102 MOVE_RIGHT
# 103 MOVE_RIGHT
# 104 NONE
# 105 MOVE_LEFT
# 106 MOVE_LEFT
# 107 NONE
# 108 MOVE_RIGHT
# 109 MOVE_RIGHT
# 110 NONE
# 111 MOVE_LEFT
# 112 MOVE_LEFT
# 113 NONE
# 114 MOVE_RIGHT
# 115 MOVE_RIGHT
# 116 NONE
# 117 MOVE_LEFT
# 118 MOVE_RIGHT
# 119 MOVE_LEFT
# 120 MOVE_LEFT
# 121 MOVE_LEFT
# 122 MOVE_LEFT
# 123 MOVE_LEFT
# 124 NONE
# 125 MOVE_LEFT
# 126 MOVE_LEFT
# 127 MOVE_LEFT
# 128 MOVE_LEFT
# 129 MOVE_LEFT
# 130 MOVE_LEFT
# 131 MOVE_LEFT
# 132 MOVE_LEFT
# 133 NONE
# 134 MOVE_RIGHT
# 135 MOVE_RIGHT
# 136 MOVE_RIGHT
# 137 NONE
# 138 MOVE_RIGHT
# 139 MOVE_RIGHT
# 140 MOVE_RIGHT
# 141 MOVE_RIGHT
# 142 MOVE_RIGHT
# 143 MOVE_RIGHT
# 144 MOVE_RIGHT
# 145 MOVE_RIGHT
# 146 MOVE_RIGHT
# 147 MOVE_RIGHT
# 148 NONE
# 149 MOVE_LEFT
# 150 MOVE_LEFT
# 151 NONE
# 152 MOVE_RIGHT
# 153 MOVE_RIGHT
# 154 NONE
# 155 MOVE_LEFT
# 156 MOVE_LEFT
# 157 NONE
# 158 MOVE_RIGHT
# 159 MOVE_RIGHT
# 160 NONE
# 161 MOVE_LEFT
# 162 MOVE_LEFT
# 163 NONE
# 164 MOVE_RIGHT
# 165 MOVE_RIGHT
# 166 NONE
# 167 MOVE_LEFT
# 168 MOVE_LEFT
# 169 NONE
# 170 MOVE_RIGHT
# 171 MOVE_RIGHT
# 172 NONE
# 173 MOVE_LEFT
# 174 MOVE_LEFT
# 175 NONE
# 176 MOVE_RIGHT
# 177 MOVE_RIGHT
# 178 NONE
# 179 MOVE_LEFT
# 180 MOVE_LEFT
# 181 MOVE_LEFT
# 182 MOVE_LEFT
# 183 MOVE_RIGHT
# 184 MOVE_LEFT
# 185 MOVE_LEFT
# 186 MOVE_LEFT
# 187 NONE
# 188 MOVE_RIGHT
# 189 MOVE_RIGHT
# 190 NONE
# 191 MOVE_LEFT
# 192 MOVE_LEFT
# 193 NONE
# 194 MOVE_RIGHT
# 195 NONE
# 196 NONE
# 197 NONE
# 198 NONE
# 199 MOVE_LEFT
# 200 NONE
# 201 MOVE_RIGHT
# 202 MOVE_RIGHT
# 203 MOVE_LEFT
# 204 MOVE_LEFT
# 205 NONE
# 206 NONE
# 207 MOVE_RIGHT
# 208 MOVE_RIGHT
# 209 NONE
# 210 MOVE_LEFT
# 211 MOVE_LEFT
# 212 NONE
# 213 MOVE_RIGHT
# 214 MOVE_RIGHT
# 215 NONE
# 216 MOVE_LEFT
# 217 NONE
# 218 NONE
# 219 MOVE_RIGHT
# 220 MOVE_RIGHT
# 221 MOVE_RIGHT
# 222 MOVE_RIGHT
# 223 MOVE_RIGHT
# 224 NONE
# 225 MOVE_LEFT
# 226 MOVE_LEFT
# 227 NONE
# 228 MOVE_RIGHT
# 229 MOVE_RIGHT
# 230 NONE
# 231 MOVE_LEFT
# 232 MOVE_LEFT
# 233 NONE
# 234 MOVE_RIGHT
# 235 MOVE_RIGHT
# 236 NONE
# 237 MOVE_LEFT
# 238 MOVE_LEFT
# 239 NONE
# 240 MOVE_RIGHT
# 241 MOVE_RIGHT
# 242 NONE
# 243 MOVE_LEFT
# 244 MOVE_LEFT
# 245 NONE
# 246 MOVE_RIGHT
# 247 MOVE_RIGHT
# 248 NONE
# 249 MOVE_LEFT
# 250 MOVE_LEFT
# 251 NONE
# 252 MOVE_RIGHT
# 253 MOVE_RIGHT
# 254 NONE
# 255 MOVE_LEFT
# 256 MOVE_LEFT
# 257 NONE
# 258 MOVE_LEFT
# 259 MOVE_LEFT
# 260 MOVE_LEFT
# 261 MOVE_LEFT
# 262 NONE
# 263 MOVE_RIGHT
# 264 MOVE_RIGHT
# 265 MOVE_LEFT
# 266 MOVE_LEFT
# 267 MOVE_LEFT
# 268 MOVE_RIGHT
# 269 MOVE_RIGHT
# 270 NONE
# 271 NONE
# 272 MOVE_LEFT
# 273 MOVE_LEFT
# 274 MOVE_RIGHT
# 275 MOVE_RIGHT
# 276 MOVE_RIGHT
# 277 MOVE_LEFT
# 278 MOVE_LEFT
# 279 MOVE_LEFT
# 280 NONE
# 281 MOVE_RIGHT
# 282 MOVE_RIGHT
# 283 MOVE_RIGHT
# 284 MOVE_LEFT
# 285 MOVE_LEFT
# 286 NONE
# 287 MOVE_LEFT
# 288 NONE
# 289 NONE
# 290 MOVE_RIGHT
# 291 MOVE_RIGHT
# 292 NONE
# 293 MOVE_LEFT
# 294 MOVE_LEFT
# 295 NONE
# 296 MOVE_RIGHT
# 297 MOVE_RIGHT
# 298 MOVE_RIGHT
# 299 MOVE_RIGHT
# 300 MOVE_RIGHT
# 301 MOVE_RIGHT
# 302 MOVE_RIGHT
# 303 NONE
# 304 MOVE_LEFT
# 305 MOVE_LEFT
# 306 NONE
# 307 MOVE_RIGHT
# 308 MOVE_RIGHT
# 309 NONE
# 310 MOVE_LEFT
# 311 MOVE_LEFT
# 312 NONE
# 313 MOVE_RIGHT
# 314 MOVE_RIGHT
# 315 NONE
# 316 MOVE_LEFT
# 317 MOVE_LEFT
# 318 NONE
# 319 MOVE_RIGHT
# 320 MOVE_RIGHT
# 321 NONE
# 322 MOVE_LEFT
# 323 MOVE_LEFT
# 324 NONE
# 325 MOVE_RIGHT
# 326 MOVE_RIGHT
# 327 NONE
# 328 MOVE_LEFT
# 329 MOVE_LEFT
# 330 MOVE_LEFT
# 331 MOVE_RIGHT
# 332 MOVE_RIGHT
# 333 NONE
# 334 MOVE_LEFT
# 335 MOVE_LEFT
# 336 NONE
# 337 MOVE_RIGHT
# 338 MOVE_RIGHT
# 339 MOVE_RIGHT
# 340 MOVE_LEFT
# 341 MOVE_LEFT
# 342 MOVE_LEFT
# 343 MOVE_RIGHT
# 344 MOVE_RIGHT
# 345 MOVE_RIGHT
# 346 NONE
# 347 MOVE_LEFT
# 348 MOVE_LEFT
# 349 NONE
# 350 MOVE_RIGHT
# 351 MOVE_RIGHT
# 352 NONE
# 353 MOVE_LEFT
# 354 MOVE_LEFT
# 355 NONE
# 356 MOVE_RIGHT
# 357 MOVE_RIGHT
# 358 NONE
# 359 MOVE_LEFT
# 360 MOVE_LEFT
# 361 NONE
# 362 MOVE_RIGHT
# 363 MOVE_LEFT
# 364 MOVE_LEFT
# 365 MOVE_LEFT
# 366 MOVE_LEFT
# 367 MOVE_LEFT
# 368 MOVE_LEFT
# 369 MOVE_LEFT
# 370 MOVE_LEFT
# 371 MOVE_RIGHT
# 372 MOVE_RIGHT
# 373 MOVE_RIGHT
# 374 NONE
# 375 NONE
# 376 MOVE_LEFT
# 377 MOVE_LEFT
# 378 NONE
# 379 MOVE_RIGHT
# 380 MOVE_RIGHT
# 381 NONE
# 382 MOVE_LEFT
# 383 NONE
# 384 NONE
# 385 MOVE_LEFT
# 386 MOVE_RIGHT
# 387 MOVE_RIGHT
# 388 NONE
# 389 MOVE_LEFT
# 390 MOVE_LEFT
# 391 MOVE_LEFT
# 392 NONE
# 393 NONE
# 394 MOVE_RIGHT
# 395 MOVE_RIGHT
# 396 MOVE_RIGHT
# 397 MOVE_RIGHT
# 398 MOVE_RIGHT
# 399 MOVE_RIGHT
# 400 MOVE_RIGHT
# 401 MOVE_RIGHT
# 402 MOVE_RIGHT
# 403 NONE
# 404 MOVE_LEFT
# 405 MOVE_LEFT
# 406 NONE
# 407 MOVE_RIGHT
# 408 MOVE_RIGHT
# 409 NONE
# 410 MOVE_LEFT
# 411 MOVE_LEFT
# 412 NONE
# 413 MOVE_RIGHT
# 414 MOVE_RIGHT
# 415 NONE
# 416 MOVE_LEFT
# 417 MOVE_LEFT
# 418 NONE
# 419 MOVE_RIGHT
# 420 MOVE_RIGHT
# 421 NONE
# 422 MOVE_LEFT
# 423 MOVE_LEFT
# 424 NONE
# 425 MOVE_RIGHT
# 426 MOVE_RIGHT
# 427 MOVE_LEFT
# 428 MOVE_RIGHT
# 429 MOVE_RIGHT
# 430 MOVE_RIGHT
# 431 MOVE_RIGHT
# 432 MOVE_RIGHT
# 433 MOVE_RIGHT
# 434 MOVE_RIGHT
# 435 MOVE_RIGHT
# 436 MOVE_RIGHT
# 437 MOVE_RIGHT
# 438 MOVE_RIGHT
# 439 MOVE_RIGHT
# 440 NONE
# 441 MOVE_LEFT
# 442 MOVE_LEFT
# 443 NONE
# 444 NONE
# 445 MOVE_RIGHT
# 446 NONE
# 447 MOVE_LEFT
# 448 NONE
# 449 MOVE_RIGHT
# 450 MOVE_RIGHT
# 451 NONE
# 452 MOVE_LEFT
# 453 MOVE_LEFT
# 454 MOVE_RIGHT
# 455 MOVE_RIGHT
# 456 NONE
# 457 MOVE_LEFT
# 458 MOVE_LEFT
# 459 MOVE_LEFT
# 460 MOVE_LEFT
# 461 MOVE_LEFT
# 462 MOVE_LEFT
# 463 MOVE_LEFT
# 464 MOVE_LEFT
# 465 MOVE_LEFT
# 466 MOVE_LEFT
# 467 MOVE_LEFT
# 468 MOVE_LEFT
# 469 MOVE_LEFT
# 470 NONE
# 471 MOVE_RIGHT
# 472 MOVE_RIGHT
# 473 NONE
# 474 MOVE_LEFT
# 475 MOVE_LEFT
# 476 NONE
# 477 MOVE_RIGHT
# 478 MOVE_RIGHT
# 479 NONE
# 480 MOVE_LEFT
# 481 MOVE_LEFT
# 482 NONE
# 483 MOVE_RIGHT
# 484 MOVE_RIGHT
# 485 NONE
# 486 MOVE_LEFT
# 487 MOVE_LEFT
# 488 NONE
# 489 MOVE_RIGHT
# 490 MOVE_LEFT
# 491 MOVE_LEFT
# 492 MOVE_LEFT
# 493 NONE
# 494 MOVE_LEFT
# 495 MOVE_RIGHT
# 496 MOVE_RIGHT
# 497 NONE
# 498 MOVE_LEFT
# 499 MOVE_LEFT
# 500 NONE
# 501 NONE
# 502 MOVE_RIGHT
# 503 MOVE_RIGHT
# 504 MOVE_RIGHT
# 505 MOVE_LEFT
# 506 MOVE_LEFT
# 507 MOVE_LEFT
# 508 NONE
# 509 MOVE_RIGHT
# 510 MOVE_RIGHT
# 511 MOVE_LEFT
# 512 MOVE_LEFT
# 513 MOVE_LEFT
# 514 MOVE_RIGHT
# 515 MOVE_RIGHT
# 516 NONE
# 517 MOVE_LEFT
# 518 MOVE_RIGHT
# 519 MOVE_RIGHT
# 520 MOVE_RIGHT
# 521 MOVE_RIGHT
# 522 MOVE_RIGHT
# 523 NONE
# 524 MOVE_LEFT
# 525 MOVE_LEFT
# 526 NONE
# 527 MOVE_RIGHT
# 528 MOVE_RIGHT
# 529 NONE
# 530 MOVE_LEFT
# 531 MOVE_LEFT
# 532 NONE
# 533 MOVE_RIGHT
# 534 MOVE_RIGHT
# 535 NONE
# 536 MOVE_LEFT
# 537 MOVE_LEFT
# 538 NONE
# 539 MOVE_RIGHT
# 540 MOVE_RIGHT
# 541 NONE
# 542 MOVE_LEFT
# 543 MOVE_LEFT
# 544 NONE
# 545 MOVE_RIGHT
# 546 MOVE_LEFT
# 547 MOVE_LEFT
# 548 MOVE_LEFT
# 549 MOVE_LEFT
# 550 MOVE_LEFT
# 551 MOVE_LEFT
# 552 MOVE_LEFT
# 553 MOVE_LEFT
# 554 MOVE_LEFT
# 555 MOVE_LEFT
# 556 MOVE_LEFT
# 557 MOVE_LEFT
# 558 MOVE_LEFT
# 559 MOVE_RIGHT
# 560 MOVE_LEFT
# 561 MOVE_LEFT
# 562 MOVE_LEFT
# 563 NONE
# 564 NONE
# 565 MOVE_RIGHT
# 566 MOVE_RIGHT
# 567 NONE
# 568 MOVE_LEFT
# 569 MOVE_LEFT
# 570 MOVE_LEFT
# 571 MOVE_RIGHT
# 572 MOVE_RIGHT
# 573 NONE
# 574 MOVE_RIGHT
# 575 MOVE_RIGHT
# 576 MOVE_RIGHT
# 577 MOVE_RIGHT
# 578 MOVE_RIGHT
# 579 MOVE_RIGHT
# 580 MOVE_RIGHT
# 581 MOVE_RIGHT
# 582 MOVE_RIGHT
# 583 MOVE_RIGHT
# 584 MOVE_RIGHT
# 585 MOVE_RIGHT
# 586 MOVE_RIGHT
# 587 MOVE_RIGHT
# 588 MOVE_RIGHT
# 589 NONE
# 590 MOVE_LEFT
# 591 MOVE_LEFT
# 592 NONE
# 593 MOVE_RIGHT
# 594 MOVE_RIGHT
# 595 NONE
# 596 MOVE_LEFT
# 597 MOVE_LEFT
# 598 NONE
# 599 MOVE_RIGHT
# 600 MOVE_RIGHT
# 601 NONE
# 602 MOVE_LEFT
# 603 MOVE_LEFT
# 604 MOVE_LEFT
# 605 MOVE_LEFT
# 606 MOVE_LEFT
# 607 MOVE_LEFT
# 608 MOVE_LEFT
# 609 MOVE_LEFT
# 610 MOVE_LEFT
# 611 MOVE_LEFT
# 612 MOVE_LEFT
# 613 MOVE_LEFT
# 614 MOVE_LEFT
# 615 MOVE_RIGHT
# 616 MOVE_LEFT
# 617 MOVE_LEFT
# 618 MOVE_LEFT
# 619 MOVE_LEFT
# 620 MOVE_LEFT
# 621 MOVE_LEFT
# 622 MOVE_LEFT
# 623 MOVE_LEFT
# 624 MOVE_LEFT
# 625 MOVE_LEFT
# 626 MOVE_LEFT
# 627 MOVE_LEFT
# 628 MOVE_RIGHT
# 629 MOVE_RIGHT
# 630 MOVE_RIGHT
# 631 MOVE_RIGHT
# 632 MOVE_RIGHT
# 633 MOVE_RIGHT
# 634 MOVE_RIGHT
# 635 MOVE_RIGHT
# 636 MOVE_RIGHT
# 637 MOVE_RIGHT
# 638 MOVE_RIGHT
# 639 MOVE_RIGHT
# 640 MOVE_RIGHT
# 641 MOVE_RIGHT
# 642 MOVE_RIGHT
# 643 MOVE_RIGHT
# 644 MOVE_RIGHT
# 645 NONE
# 646 MOVE_LEFT
# 647 MOVE_LEFT
# 648 NONE
# 649 MOVE_RIGHT
# 650 MOVE_RIGHT
# 651 NONE
# 652 MOVE_LEFT
# 653 MOVE_LEFT
# 654 NONE
# 655 MOVE_LEFT
# 656 MOVE_LEFT
# 657 MOVE_LEFT
# 658 MOVE_LEFT
# 659 MOVE_LEFT
# 660 MOVE_LEFT
# 661 MOVE_LEFT
# 662 MOVE_LEFT
# 663 MOVE_LEFT
# 664 MOVE_LEFT
# 665 MOVE_LEFT
# 666 MOVE_LEFT
# 667 MOVE_RIGHT
# 668 MOVE_LEFT
# 669 MOVE_LEFT
# 670 MOVE_LEFT
# 671 MOVE_LEFT
# 672 MOVE_LEFT
# 673 MOVE_LEFT
# 674 MOVE_LEFT
# 675 MOVE_LEFT
# 676 MOVE_LEFT
# 677 MOVE_LEFT
# 678 MOVE_LEFT
# 679 MOVE_LEFT
# 680 None
# 681 None
# 682 MOVE_RIGHT
# 683 MOVE_RIGHT
# 684 MOVE_RIGHT
# 685 MOVE_RIGHT
# 686 MOVE_RIGHT
# 687 MOVE_RIGHT
# 688 MOVE_RIGHT
# 689 MOVE_RIGHT
# 690 MOVE_RIGHT
# 691 MOVE_RIGHT
# 692 MOVE_RIGHT
# 693 MOVE_RIGHT
# 694 MOVE_RIGHT
# 695 MOVE_RIGHT
# 696 MOVE_RIGHT
# 697 MOVE_RIGHT
# 698 MOVE_RIGHT
# 699 MOVE_RIGHT
# 700 MOVE_RIGHT
# 701 NONE
# 702 MOVE_LEFT
# 703 MOVE_LEFT
# 704 MOVE_LEFT
# 705 MOVE_LEFT
# 706 MOVE_LEFT
# 707 MOVE_LEFT
# 708 MOVE_RIGHT
# 709 MOVE_LEFT
# 710 MOVE_LEFT
# 711 MOVE_LEFT
# 712 MOVE_LEFT
# 713 MOVE_LEFT
# 714 MOVE_LEFT
# 715 MOVE_LEFT
# 716 MOVE_LEFT
# 717 MOVE_LEFT
# 718 MOVE_LEFT
# 719 MOVE_LEFT
# 720 MOVE_RIGHT
# 721 MOVE_RIGHT
# 722 MOVE_RIGHT
# 723 MOVE_RIGHT
# 724 MOVE_RIGHT
# 725 MOVE_RIGHT
# 726 MOVE_RIGHT
# 727 MOVE_RIGHT
# 728 MOVE_RIGHT
# 729 MOVE_RIGHT
# 730 MOVE_RIGHT
# 731 MOVE_RIGHT
# 732 MOVE_LEFT
# 733 MOVE_LEFT
# 734 MOVE_LEFT
# 735 MOVE_RIGHT
# 736 MOVE_LEFT
# 737 MOVE_LEFT
# 738 MOVE_LEFT
# 739 MOVE_LEFT
# 740 MOVE_LEFT
# 741 MOVE_LEFT
# 742 MOVE_LEFT
# 743 MOVE_LEFT
# 744 MOVE_LEFT
# 745 MOVE_LEFT
# 746 MOVE_LEFT
# 747 MOVE_RIGHT
# 748 NONE
# 749 MOVE_RIGHT
# 750 MOVE_RIGHT
# 751 MOVE_RIGHT
# 752 MOVE_RIGHT
# 753 NONE
# 754 NONE
# 755 MOVE_LEFT
# 756 MOVE_RIGHT
# 757 MOVE_RIGHT
# 758 MOVE_RIGHT
# 759 MOVE_RIGHT
# 760 MOVE_RIGHT
# 761 MOVE_RIGHT
# 762 MOVE_RIGHT
# 763 MOVE_RIGHT
# 764 MOVE_RIGHT
# 765 MOVE_RIGHT
# 766 MOVE_RIGHT
# 767 MOVE_RIGHT
# 768 MOVE_RIGHT
# 769 NONE
# 770 MOVE_LEFT
# 771 MOVE_LEFT
# 772 MOVE_LEFT
# 773 MOVE_LEFT
# 774 MOVE_LEFT
# 775 MOVE_LEFT
# 776 NONE
# 777 MOVE_RIGHT
# 778 MOVE_RIGHT
# 779 MOVE_RIGHT
# 780 MOVE_LEFT
# 781 MOVE_RIGHT
# 782 MOVE_LEFT
# 783 MOVE_LEFT
# 784 MOVE_LEFT
# 785 MOVE_LEFT
# 786 MOVE_LEFT
# 787 MOVE_LEFT
# 788 MOVE_LEFT
# 789 MOVE_LEFT
# 790 MOVE_LEFT
# 791 MOVE_LEFT
# 792 MOVE_RIGHT
# 793 MOVE_RIGHT
# 794 MOVE_RIGHT
# 795 MOVE_RIGHT
# 796 MOVE_RIGHT
# 797 MOVE_RIGHT
# 798 MOVE_RIGHT
# 799 MOVE_RIGHT
# 800 MOVE_RIGHT
# 801 MOVE_RIGHT
# 802 MOVE_RIGHT
# 803 MOVE_RIGHT
# 804 MOVE_LEFT
# 805 MOVE_LEFT
# 806 MOVE_LEFT
# 807 MOVE_LEFT
# 808 MOVE_RIGHT
# 809 MOVE_LEFT
# 810 MOVE_LEFT
# 811 MOVE_LEFT
# 812 MOVE_LEFT
# 813 MOVE_LEFT
# 814 MOVE_LEFT
# 815 MOVE_LEFT
# 816 MOVE_LEFT
# 817 MOVE_LEFT
# 818 NONE
# 819 MOVE_RIGHT
# 820 MOVE_RIGHT
# 821 MOVE_RIGHT
# 822 MOVE_RIGHT
# 823 MOVE_RIGHT
# 824 NONE
# 825 NONE
# 826 MOVE_LEFT
# 827 MOVE_RIGHT
# 828 MOVE_RIGHT
# 829 MOVE_RIGHT
# 830 MOVE_RIGHT
# 831 MOVE_RIGHT
# 832 MOVE_RIGHT
# 833 MOVE_RIGHT
# 834 MOVE_RIGHT
# 835 MOVE_RIGHT
# 836 NONE
# 837 MOVE_LEFT
# 838 MOVE_LEFT
# 839 MOVE_LEFT
# 840 MOVE_LEFT
# 841 MOVE_LEFT
# 842 MOVE_LEFT
# 843 NONE
# 844 MOVE_RIGHT
# 845 MOVE_RIGHT
# 846 MOVE_RIGHT
# 847 MOVE_RIGHT
# 848 MOVE_RIGHT
# 849 MOVE_RIGHT
# 850 MOVE_RIGHT
# 851 MOVE_LEFT
# 852 MOVE_LEFT
# 853 MOVE_LEFT
# 854 MOVE_LEFT
# 855 MOVE_LEFT
# 856 MOVE_LEFT
# 857 MOVE_LEFT
# 858 MOVE_LEFT
# 859 MOVE_LEFT
# 860 MOVE_LEFT
# 861 MOVE_RIGHT
# 862 MOVE_RIGHT
# 863 MOVE_RIGHT
# 864 MOVE_RIGHT
# 865 MOVE_RIGHT
# 866 MOVE_RIGHT
# 867 MOVE_RIGHT
# 868 MOVE_RIGHT
# 869 MOVE_RIGHT
# 870 NONE
# 871 MOVE_LEFT
# 872 MOVE_LEFT
# 873 MOVE_LEFT
# 874 MOVE_LEFT
# 875 MOVE_LEFT
# 876 MOVE_RIGHT
# 877 MOVE_LEFT
# 878 MOVE_LEFT
# 879 MOVE_LEFT
# 880 MOVE_LEFT
# 881 MOVE_LEFT
# 882 MOVE_LEFT
# 883 MOVE_LEFT
# 884 MOVE_LEFT
# 885 MOVE_LEFT
# 886 MOVE_LEFT
# 887 MOVE_RIGHT
# 888 MOVE_RIGHT
# 889 MOVE_RIGHT
# 890 MOVE_RIGHT
# 891 MOVE_RIGHT
# 892 MOVE_RIGHT
# 893 MOVE_RIGHT
# 894 NONE
# 895 MOVE_RIGHT
# 896 MOVE_RIGHT
# 897 MOVE_RIGHT
# 898 MOVE_RIGHT
# 899 MOVE_RIGHT
# 900 MOVE_RIGHT
# 901 MOVE_RIGHT
# 902 NONE
# 903 MOVE_LEFT
# 904 MOVE_LEFT
# 905 MOVE_LEFT
# 906 MOVE_LEFT
# 907 MOVE_LEFT
# 908 MOVE_LEFT
# 909 NONE
# 910 MOVE_RIGHT
# 911 MOVE_RIGHT
# 912 MOVE_RIGHT
# 913 MOVE_RIGHT
# 914 MOVE_RIGHT
# 915 MOVE_RIGHT
# 916 NONE
# 917 MOVE_LEFT
# 918 MOVE_LEFT
# 919 MOVE_LEFT
# 920 MOVE_LEFT
# 921 MOVE_LEFT
# 922 MOVE_LEFT
# 923 MOVE_LEFT
# 924 MOVE_LEFT
# 925 MOVE_LEFT
# 926 MOVE_LEFT
# 927 MOVE_RIGHT
# 928 MOVE_RIGHT
# 929 MOVE_RIGHT
# 930 MOVE_RIGHT
# 931 MOVE_RIGHT
# 932 MOVE_RIGHT
# 933 MOVE_RIGHT
# 934 MOVE_RIGHT
# 935 MOVE_RIGHT
# 936 MOVE_RIGHT
# 937 MOVE_RIGHT
# 938 MOVE_LEFT
# 939 MOVE_LEFT
# 940 MOVE_LEFT
# 941 MOVE_LEFT
# 942 MOVE_LEFT
# 943 MOVE_LEFT
# 944 MOVE_LEFT
# 945 MOVE_LEFT
# 946 MOVE_LEFT
# 947 MOVE_LEFT
# 948 MOVE_LEFT
# 949 MOVE_LEFT
# 950 MOVE_LEFT
# 951 MOVE_RIGHT
# 952 MOVE_LEFT
# 953 MOVE_RIGHT
# 954 MOVE_RIGHT
# 955 NONE
# 956 MOVE_RIGHT
# 957 MOVE_RIGHT
# 958 MOVE_RIGHT
# 959 MOVE_RIGHT
# 960 MOVE_RIGHT
# 961 MOVE_RIGHT
# 962 MOVE_RIGHT
# 963 MOVE_RIGHT
# 964 MOVE_RIGHT
# 965 MOVE_RIGHT
# 966 NONE
# 967 MOVE_LEFT
# 968 MOVE_LEFT
# 969 MOVE_LEFT
# 970 MOVE_LEFT
# 971 MOVE_LEFT
# 972 MOVE_LEFT
# 973 NONE
# 974 MOVE_RIGHT
# 975 MOVE_RIGHT
# 976 MOVE_RIGHT
# 977 MOVE_RIGHT
# 978 MOVE_RIGHT
# 979 MOVE_LEFT
# 980 MOVE_LEFT
# 981 MOVE_LEFT
# 982 MOVE_LEFT
# 983 MOVE_LEFT
# 984 MOVE_LEFT
# 985 MOVE_LEFT
# 986 MOVE_LEFT
# 987 MOVE_LEFT
# 988 MOVE_LEFT
# 989 MOVE_LEFT
# 990 NONE
# 991 MOVE_RIGHT
# 992 MOVE_RIGHT
# 993 MOVE_RIGHT
# 994 MOVE_RIGHT
# 995 MOVE_RIGHT
# 996 MOVE_RIGHT
# 997 MOVE_RIGHT
# 998 MOVE_RIGHT
# 999 MOVE_RIGHT
# 1000 MOVE_RIGHT
# 1001 MOVE_RIGHT
# 1002 MOVE_RIGHT
# 1003 NONE
# 1004 MOVE_LEFT
# 1005 MOVE_LEFT
# 1006 MOVE_LEFT
# 1007 MOVE_LEFT
# 1008 MOVE_LEFT
# 1009 MOVE_LEFT
# 1010 NONE
# 1011 MOVE_RIGHT
# 1012 MOVE_RIGHT
# 1013 MOVE_RIGHT
# 1014 MOVE_RIGHT
# 1015 MOVE_RIGHT
# 1016 MOVE_RIGHT
# 1017 NONE
# 1018 MOVE_LEFT
# 1019 MOVE_LEFT
# 1020 MOVE_LEFT
# 1021 MOVE_LEFT
# 1022 MOVE_LEFT
# 1023 MOVE_LEFT
# 1024 MOVE_LEFT
# 1025 MOVE_LEFT
# 1026 MOVE_LEFT
# 1027 MOVE_LEFT
# 1028 MOVE_LEFT
# 1029 NONE
# 1030 NONE
# 1031 MOVE_RIGHT
# 1032 MOVE_RIGHT
# 1033 MOVE_RIGHT
# 1034 MOVE_RIGHT
# 1035 MOVE_RIGHT
# 1036 MOVE_RIGHT
# 1037 MOVE_RIGHT
# 1038 NONE
# 1039 MOVE_LEFT
# 1040 MOVE_RIGHT
# 1041 MOVE_RIGHT
# 1042 MOVE_RIGHT
# 1043 MOVE_RIGHT
# 1044 MOVE_RIGHT
# 1045 NONE
# 1046 MOVE_LEFT
# 1047 MOVE_LEFT
# 1048 MOVE_LEFT
# 1049 MOVE_LEFT
# 1050 MOVE_LEFT
# 1051 MOVE_LEFT
# 1052 NONE
# 1053 MOVE_RIGHT
# 1054 MOVE_RIGHT
# 1055 MOVE_RIGHT
# 1056 MOVE_RIGHT
# 1057 MOVE_RIGHT
# 1058 MOVE_RIGHT
# 1059 NONE
# 1060 MOVE_RIGHT
# 1061 MOVE_LEFT
# 1062 MOVE_LEFT
# 1063 MOVE_LEFT
# 1064 MOVE_RIGHT
# 1065 MOVE_LEFT
# 1066 MOVE_LEFT
# 1067 MOVE_LEFT
# 1068 MOVE_LEFT
# 1069 MOVE_LEFT
# 1070 MOVE_RIGHT
# 1071 MOVE_LEFT
# 1072 NONE
# 1073 NONE
# 1074 NONE
# 1075 MOVE_RIGHT
# 1076 MOVE_LEFT
# 1077 MOVE_LEFT
# 1078 MOVE_LEFT
# 1079 MOVE_LEFT
# 1080 MOVE_RIGHT
# 1081 MOVE_RIGHT
# 1082 MOVE_RIGHT
# 1083 MOVE_RIGHT
# 1084 MOVE_RIGHT
# 1085 MOVE_RIGHT
# 1086 MOVE_RIGHT
# 1087 MOVE_RIGHT
# 1088 MOVE_RIGHT
# 1089 NONE
# 1090 MOVE_LEFT
# 1091 MOVE_LEFT
# 1092 MOVE_LEFT
# 1093 MOVE_LEFT
# 1094 MOVE_LEFT
# 1095 MOVE_LEFT
# 1096 NONE
# 1097 MOVE_RIGHT
# 1098 MOVE_RIGHT
# 1099 MOVE_RIGHT
# 1100 MOVE_RIGHT
# 1101 NONE
# 1102 MOVE_LEFT
# 1103 MOVE_LEFT
# 1104 MOVE_LEFT
# 1105 MOVE_LEFT
# 1106 MOVE_LEFT
# 1107 MOVE_LEFT
# 1108 MOVE_LEFT
# 1109 MOVE_RIGHT
# 1110 MOVE_RIGHT
# 1111 MOVE_RIGHT
# 1112 MOVE_RIGHT
# 1113 MOVE_RIGHT
# 1114 MOVE_RIGHT
# 1115 MOVE_RIGHT
# 1116 MOVE_RIGHT
# 1117 MOVE_RIGHT
# 1118 MOVE_LEFT
# 1119 MOVE_RIGHT
# 1120 MOVE_RIGHT
# 1121 MOVE_RIGHT
# 1122 MOVE_RIGHT
# 1123 MOVE_RIGHT
# 1124 MOVE_RIGHT
# 1125 NONE
# 1126 MOVE_LEFT
# 1127 MOVE_LEFT
# 1128 MOVE_LEFT
# 1129 MOVE_LEFT
# 1130 MOVE_LEFT
# 1131 NONE
# 1132 NONE
# 1133 MOVE_RIGHT
# 1134 MOVE_RIGHT
# 1135 MOVE_RIGHT
# 1136 MOVE_RIGHT
# 1137 MOVE_LEFT
# 1138 MOVE_LEFT
# 1139 MOVE_LEFT
# 1140 MOVE_LEFT
# 1141 MOVE_LEFT
# 1142 MOVE_LEFT
# 1143 MOVE_LEFT
# 1144 MOVE_LEFT
# 1145 MOVE_LEFT
# 1146 MOVE_LEFT
# 1147 NONE
# 1148 MOVE_RIGHT
# 1149 MOVE_RIGHT
# 1150 MOVE_RIGHT
# 1151 MOVE_RIGHT
# 1152 MOVE_RIGHT
# 1153 MOVE_RIGHT
# 1154 NONE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4308865f630c> in <module>
#      22 for i, s in enumerate(scene_command[1:-2]):
#      23     count = count + 1
# ---> 24     print(count, s[1])
#      25 for i, s in enumerate(scene_command[1:-2]):
#      26     print(s[0], s[1])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#資料劃分
x_train, x_test, y_train, y_test = train_test_split(feature, answer, test_size=0.3, random_state=9)
#參數區間
param_grid = {'n_neighbors':[1, 2, 3]}
#交叉驗證 
cv = StratifiedShuffleSplit(n_splits=3, test_size=0.3, random_state=9)
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=cv, verbose=10, n_jobs=6) #n_jobs為平行運算的數量
grid.fit(x_train, y_train)
grid_predictions = grid.predict(x_test)

#儲存
file = open('model.pickle', 'wb')
pickle.dump(grid, file)
file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-fa92cabdcf2e> in <module>
#       1 #資料劃分
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(feature, answer, test_size=0.3, random_state=9)
#       3 #參數區間
#       4 param_grid = {'n_neighbors':[1, 2, 3]}
#       5 #交叉驗證
#
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2116         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2117
# -> 2118     arrays = indexable(*arrays)
#    2119
#    2120     n_samples = _num_samples(arrays[0])
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [41278, 0]

# %%
#最佳參數
print(grid.best_params_)
#預測結果
#print(grid_predictions)
#混淆矩陣
print(confusion_matrix(y_test, grid_predictions))
#分類結果
print(classification_report(y_test, grid_predictions))
# Out:
# {'n_neighbors': 1}
# [[12384]]
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00     12384
#
#     accuracy                           1.00     12384
#    macro avg       1.00      1.00      1.00     12384
# weighted avg       1.00      1.00      1.00     12384
